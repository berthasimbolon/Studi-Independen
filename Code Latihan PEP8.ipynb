# %% [markdown]
# Activity
# 1. Code Refactoring
# 1.1 Ubah gaya penulisan kode program berikut sesuai dengan standar PEP8

# %%
#program untuk menghitung luas dan keliling lingkaran
phi = 3.14

def luas_lingkaran(jari_jari):
    luas = phi * jari_jari**2
    return luas

def keliling_lingkaran(jari_jari):
    keliling = 2 * Pi * jari_jari
    return keliling

def tampilkan_menu():
    print('')
    print("")
    print( 'Program untuk menghitung luas dan keliling lingkaran')
    print( 'Mau ngitung apa nih bre?')
    print( '1. Luas Lingkaran')
    print( '2. Keliling Lingkaran')
    print( '3. Stop Program')
    print('')

pil = 'bukan 3'
while pil!= 3:
    tampilkan_menu()
    pil = input('Pilihan:')

    if pil=='1':
        jari_jari = input('Jari Jari:')
        jari_jari = float(jari_jari)
        hasil = luas_lingkaran(jari_jari)
        print("Luas Lingkaran:", hasil )

    elif pil == '2':
        jari_jari = input('Jari Jari:')
        jari_jari = float(jari_jari)
        hasil = luas_lingkaran(jari_jari)
        print("Keliling Lingkaran:", hasil )

    elif pil == '3':
        print( "TERIMA KASIH SUDAH MENGGUNAKAN PROGRAM KAMI")
        break

    else:
        print('Pilihan tidak tersedia')
        tampilkan_menu()
# Out:
# Program untuk menghitung luas dan keliling lingkaran
# Mau ngitung apa nih bre?
# 1. Luas Lingkaran
# 2. Keliling Lingkaran
# 3. Stop Program

# %% [markdown]
# 1.2 Ubah gaya penulisan kode program berikut sesuai dengan standar PEP8

# %%
# Main Layangan
# Requirement:
# - Gak Hujan
# - Kecepatan Angin 5 - 30 km/s

#Clues:
# - Naming variable dan function, whitespace, komentar
# - Terdapat kode duplikat, coba perbaiki

def main_layangan():
  hujan = input("Lagi ujan ga? (y/n)")
  if hujan == 'y' or hujan == 'Y':
    hujan = True
  else:
    hujan = False

  kecepatan_angin = input("Masukkan kecepatan angin = ")

  if hujan == True:
    print("Gak bisa main layangan")
    return False
  
  elif kecepatan_angin>=5 and kecepatan_angin<=30:
      print('Asiik, gass main layangan')
      return True
  else:
      print("Skip, mending main ep ep")
      return False

  if capek == True:
    print("Istirahat")
  else:
    print("Gass main ep ep")
    main_layangan()

# %% [markdown]
# 2. Memilih delegasi Tim Sudirman Cup dari Indonesia
# Berikut adalah data nama pemain bulu tangkis Indonesia beserta medali yang sudah diraih selama 2020 - 2021:

# %%
# DataFrame 
import pandas as pd

# %%
pemain_dan_medali = [[7, "Ginting"], [5, "Jonathan C."], [9," Hendra"], [9," Ahsan"], [8, "Markus"], [8, "Kevin"], [4, "Gregoria"], 
                     [6, "Praven"], [6, "Melati"], [7, "Greysia"], [7, "Apriani"], [5, "Putri"], [5, "Rian"], [5, "Fajar"]]

# %%
 df1 =pd.DataFrame([[7, "Ginting"],
                        [5, "Jonathan C."], 
                        [9, "Hendra"],
                        [9, "Ahsan"],
                        [8, "Markus"],
                        [8, "Kevin"],
                        [4, "Gregoria"], 
                        [6, "Praven"],
                        [6, "Melati"], 
                        [7, "Greysia"],
                        [7, "Apriani"],
                        [5, "Putri"], 
                        [5, "Rian"], 
                        [5, "Fajar"]])

df1.columns = ["Jumlah medali","Nama"]

df1
# Out:
#     Jumlah medali         Nama
# 0               7      Ginting
# 1               5  Jonathan C.
# 2               9       Hendra
# 3               9        Ahsan
# 4               8       Markus
# 5               8        Kevin
# 6               4     Gregoria
# 7               6       Praven
# 8               6       Melati
# 9               7      Greysia
# 10              7      Apriani
# 11              5        Putri
# 12              5         Rian
# 13              5        Fajar

# %%
df1.to_csv('pemain_dan_medali.csv')
df1.to_excel('pemain_dan_medali.xlsx')

# %% [markdown]
# Buatlah program seleksi pemain bulu tangkis untuk Tim Sudirman dengan menerapkan konsep Clean Code

# %%
# Buat list baru dengan mengurutkan list diatas berdasarkan medali yang diraih dari yang paling banyak
# Nama pemenang medali yang paling sedikit

min(pemain_dan_medali)
# Out:
# [4, 'Gregoria']

# %%
#sort, mengurutkan

pemain_dan_medali.sort()
print(pemain_dan_medali)
# Out:
# [[4, 'Gregoria'], [5, 'Fajar'], [5, 'Jonathan C.'], [5, 'Putri'], [5, 'Rian'], [6, 'Melati'], [6, 'Praven'], [7, 'Apriani'], [7, 'Ginting'], [7, 'Greysia'], [8, 'Kevin'], [8, 'Markus'], [9, ' Ahsan'], [9, ' Hendra']]

# %%
# Nama pemenang medali terbanyak

max(pemain_dan_medali)
# Out:
# [9, ' Hendra']

# %%
# Dengan looping, buatlah 2 list terpisah dari pemain dan juga medalinya, namun urutannya harus tetap sama dengan yang diatas

nama_pemain = ['Gregoria', 'Fajar', 
               'Jonathan C.','Putri','Rian', 
               'melati', 'Praven', 'Apriani', 'Ginting',
               'Greysia','Kevin', 'Markus', 'Ahsan', 'Hendra']
for nama in nama_pemain:
  print(nama)
 
jumlah_medali =  [4,5,5,5,5,5,6,6,7,7,7,8,8,9,9]     

for medali in jumlah_medali:
  print(medali)
# Out:
# Gregoria
# Fajar
# Jonathan C.
# Putri
# Rian
# melati
# Praven
# Apriani
# Ginting
# Greysia
# Kevin
# Markus
# Ahsan
# Hendra
# 4
# 5
# 5
# 5
# 5
# 5
# 6
# 6
# 7
# 7
# 7
# 8
# 8
# 9
# 9

# %%
for nama,medali in zip(nama_pemain,jumlah_medali):
    print(nama,'jumlah medali yang diperoleh:', medali)
# Out:
# Gregoria jumlah medali yang diperoleh: 4
# Fajar jumlah medali yang diperoleh: 5
# Jonathan C. jumlah medali yang diperoleh: 5
# Putri jumlah medali yang diperoleh: 5
# Rian jumlah medali yang diperoleh: 5
# melati jumlah medali yang diperoleh: 5
# Praven jumlah medali yang diperoleh: 6
# Apriani jumlah medali yang diperoleh: 6
# Ginting jumlah medali yang diperoleh: 7
# Greysia jumlah medali yang diperoleh: 7
# Kevin jumlah medali yang diperoleh: 7
# Markus jumlah medali yang diperoleh: 8
# Ahsan jumlah medali yang diperoleh: 8
# Hendra jumlah medali yang diperoleh: 9

# %% [markdown]
# Misalkan Rio dan Dewi adalah pemain baru dengan perolehan medali : [2, "Rio"], [5, "Dewi"]. Jika maksimal 1 tim hanya 14 pemain, buatlah fungsi baru yang dapat memeriksa apakah Rio dan Dewi bisa menjadi pemain baru jika dibandingkan perolehan medalinya dengan squad tim saat ini. Output:
#
# "Nama" layak/tidak layak bergabung Tim Sudirman cup indonesia = "list pemain yg layak"

# %%
# Bikin fungsinya disini

pemain_dan_medali.extend([[2, 'Rio'], [5, 'Dewi']])
pemain_dan_medali

pemain_dan_medali.sort()
pemain_dan_medali

pemain_dan_medali.reverse()
pemain_dan_medali

print("List Pemain dan Medali")
print(pemain_dan_medali)

pemain_dan_medali.remove(min(pemain_dan_medali))
pemain_dan_medali

pemain_dan_medali1 = pemain_dan_medali

pemain_dan_medali1.remove(min(pemain_dan_medali1))
pemain_dan_medali1
print("List pemain yang layak")
print(pemain_dan_medali1)
# Out:
# List Pemain dan Medali
# [[9, ' Hendra'], [9, ' Ahsan'], [8, 'Markus'], [8, 'Kevin'], [7, 'Greysia'], [7, 'Ginting'], [7, 'Apriani'], [6, 'Praven'], [6, 'Melati'], [5, 'Rian'], [5, 'Putri'], [5, 'Jonathan C.'], [5, 'Fajar'], [5, 'Dewi'], [5, 'Dewi'], [4, 'Gregoria'], [2, 'Rio'], [2, 'Rio']]
# List pemain yang layak
# [[9, ' Hendra'], [9, ' Ahsan'], [8, 'Markus'], [8, 'Kevin'], [7, 'Greysia'], [7, 'Ginting'], [7, 'Apriani'], [6, 'Praven'], [6, 'Melati'], [5, 'Rian'], [5, 'Putri'], [5, 'Jonathan C.'], [5, 'Fajar'], [5, 'Dewi'], [5, 'Dewi'], [4, 'Gregoria']]
